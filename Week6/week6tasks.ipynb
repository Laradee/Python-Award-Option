# %%
def physicsres():
    '''store physics results'''
    with open("physres.csv", "w") as fileObj:
    print("50%", file=fileObj)
    print("90%", file=fileObj)
    print("78%", file=fileObj)

# %%
def file
name = input("what is your name:")
favcolour = input("what is your favoruite colour:")

# %%
def filereader():
    '''reads from a  text file'''
    with open("oranges.txt", "r") as fileObj:
        content = fileObj.readlines()
        print(content)
    for item in content:
        print(item)
def fileappend():
    '''add items to the file'''
    with open("oranges.txt", "a") as fileObj
        fileObj.write("\n 5. salad\n")
        print('item was successfully added!')
def newshoplist():
    '''write to a new file'''
    with open("Newlist.txt" , "w") as fileObj
        print("1. milk", file=fileObj)
        print("2. breakfast", file=fileObj)
