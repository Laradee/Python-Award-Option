# %% [markdown]
# # My first Python Notbook
# ### Week 1 programming Challenges

# %%
def Ftempoconverter():
    '''Tempreture converter'''
    temp = float(input("enter tempreture in celsius:"))
    f = (temp * 9)/5 + 32
    print(f"{temp} C is {f} F")
Ftempoconverter()

def Ftempoconverter():
    '''Tempreture converter'''
    tempf = float(input("enter tempreture in farehheight:"))
    c= (tempf-32)*5/9
    print(f"{tempf} F is {c} C")
Ftempoconverter()

# %%
def basiccalculator():
    '''basic calcuator'''
    num1 = int(input('first number:'))
    num2 = int(input('second number:'))
    print(f'sum: {num1+num2}')
    print(f'diff: {num1-num2}')
    
    
def addEm(x,y):
    '''adds and returns sum'''
    return x+y

def divideEm(x,y):
    return x/y

menu = '''
1. add
2. divide
3. quit
'''

print(menu)
userchoice = int(input('enter a menu choice:'))
if userchoice ==1:
    num1 = int(input('enter first number: '))
    num2 = int(input('enter second number'))
    print(f'the sum is {addEm(num1,num2)}')

if userchoice ==2:
    num1 = int(input('enter first number: '))
    num2 = int(input('enter second number:'))
    print(f'the value is {divideEm(num1,num2)}:')

# %%
def greet(user):
    '''Greets the named user'''
    print(f'Hello {user} nice to meet you.')

# %%
greet("Amelia")

# %%
def FTempConverter():
    '''Tem converter'''
    temp = float(input(" Enter Celcius temp: "))
    f = (temp*9)/5+32
    print(f"{temp} C is {f} F")
FTempConverter()
# Out:
# 56.0 C is 132.8 F
